# %%
import numpy as np
from skimage import io

# %%
PIC = io.imread('photo.jpg')

# %%
PIC
# Out:
# Array([[[107,  93,  64],
#         [107,  93,  64],
#         [107,  94,  62],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[108,  94,  65],
#         [108,  94,  65],
#         [109,  96,  64],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[109,  96,  64],
#         [109,  96,  64],
#         [110,  97,  65],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[105,  26,  32],
#         [103,  26,  32],
#         [102,  27,  32],
#         ...,
#         [ 84, 117, 106],
#         [ 84, 117, 106],
#         [ 87, 120, 109]],
#
#        [[105,  30,  37],
#         [102,  27,  34],
#         [ 97,  24,  31],
#         ...,
#         [ 85, 118, 107],
#         [ 80, 113, 102],
#         [ 86, 119, 110]],
#
#        [[109,  36,  43],
#         [103,  32,  38],
#         [ 95,  26,  31],
# ...

# %%
PIC.shape
# Out:
# (960, 1280, 3)

# %%
PIC.ndim
# Out:
# 3

# %%
# %matplotlib inline

# %%
io.imshow(PIC)

# %%
io.imshow(PIC[:, ::-1])

# %%
io.imshow(PIC[::-1, :])

# %%
io.imshow(PIC[::2, ::2])

# %%
io.imshow(PIC)

# %%
#300-450, 400-600
io.imshow(PIC[300:450, 400:550])

# %%
x = PIC.copy()
for i in range(960):
    for j in range(1280):
        PIC[i, j] = PIC[i, j].mean()
io.imshow(PIC)
